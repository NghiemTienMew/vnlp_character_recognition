# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/vnlp_character_recognition
# Out:
# /content/drive/MyDrive/vnlp_character_recognition

# %%
# !pip install python-Levenshtein
# Out:
# Collecting python-Levenshtein
#   Downloading python_levenshtein-0.27.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting Levenshtein==0.27.1 (from python-Levenshtein)
#   Downloading levenshtein-0.27.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from Levenshtein==0.27.1->python-Levenshtein)
#   Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Downloading python_levenshtein-0.27.1-py3-none-any.whl (9.4 kB)
# Downloading levenshtein-0.27.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 7.4 MB/s eta 0:00:00
# Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 47.4 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.27.1 python-Levenshtein-0.27.1 rapidfuzz-3.13.0

# %%
# !python scripts/train.py --config config/model_config.yaml
# Out:
# Using GPU: Tesla T4
# Creating data loaders...
# Dataset mode: train, Size: 1597
# Number of classes: 40
# Dataset mode: val, Size: 206
# Number of classes: 40
# Dataset mode: test, Size: 197
# Number of classes: 40
# Data loaders created!
# Creating model...
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100% 20.5M/20.5M [00:00<00:00, 108MB/s]
# Model created!
# Setting up training...
# Optimizer: adam, lr=0.001, weight_decay=1e-05
# Starting training for 100 epochs...
# Save directory: experiments/efficientnet_b0_20250522_080516
#
# ============================================================
# Epoch 1/100
# ============================================================
# Epoch 1 [Train]:  38% 19/50 [02:09<02:52,  5.57s/it, loss=3.0801, avg_loss=3.6504]Error in batch 19: Expected input batch_size (256) to match target batch_size (352).
# Epoch 1 [Train]:  40% 20/50 [02:18<03:17,  6.59s/it, loss=0.0000, avg_loss=3.4678]Error in batch 20: Expected input batch_size (288) to match target batch_size (352).
# Epoch 1 [Train]:  42% 21/50 [02:20<02:33,  5.28s/it, loss=0.0000, avg_loss=3.3027]Error in batch 21: Expected input batch_size (224) to match target batch_size (352).
# Epoch 1 [Train]:  44% 22/50 [02:38<04:15,  9.13s/it, loss=0.0000, avg_loss=3.1526]Error in batch 22: Expected input batch_size (256) to match target batch_size (352).
# Epoch 1 [Train]:  44% 22/50 [02:38<04:15,  9.13s/it, loss=0.0000, avg_loss=3.0155]Error in batch 23: Expected input batch_size (256) to match target batch_size (352).
# Epoch 1 [Train]:  48% 24/50 [02:50<03:17,  7.58s/it, loss=0.0000, avg_loss=2.8899]Error in batch 24: Expected input batch_size (256) to match target batch_size (352).
# Epoch 1 [Train]:  48% 24/50 [02:50<03:17,  7.58s/it, loss=0.0000, avg_loss=2.7743]Error in batch 25: Expected input batch_size (256) to match target batch_size (352).
# Epoch 1 [Train]:  52% 26/50 [03:02<02:49,  7.08s/it, loss=0.0000, avg_loss=2.6676]Error in batch 26: Expected input batch_size (256) to match target batch_size (352).
# Epoch 1 [Train]:  52% 26/50 [03:02<02:49,  7.08s/it, loss=0.0000, avg_loss=2.5688]Error in batch 27: Expected input batch_size (224) to match target batch_size (352).
# Epoch 1 [Train]:  56% 28/50 [03:12<02:18,  6.30s/it, loss=0.0000, avg_loss=2.4770]Error in batch 28: Expected input batch_size (256) to match target batch_size (352).
# Epoch 1 [Train]:  56% 28/50 [03:12<02:18,  6.30s/it, loss=0.0000, avg_loss=2.3916]Error in batch 29: Expected input batch_size (320) to match target batch_size (352).
# Epoch 1 [Train]:  60% 30/50 [03:26<02:09,  6.46s/it, loss=0.0000, avg_loss=2.3119]Error in batch 30: Expected input batch_size (288) to match target batch_size (352).
# Epoch 1 [Train]:  60% 30/50 [03:26<02:09,  6.46s/it, loss=0.0000, avg_loss=2.2373]Error in batch 31: Expected input batch_size (288) to match target batch_size (352).
# Epoch 1 [Train]:  64% 32/50 [03:39<01:57,  6.52s/it, loss=0.0000, avg_loss=2.1674]Error in batch 32: Expected input batch_size (224) to match target batch_size (352).
# Epoch 1 [Train]:  66% 33/50 [03:39<01:30,  5.32s/it, loss=0.0000, avg_loss=2.1017]Error in batch 33: Expected input batch_size (320) to match target batch_size (352).
# Epoch 1 [Train]:  68% 34/50 [03:52<01:50,  6.90s/it, loss=0.0000, avg_loss=2.0399]Error in batch 34: Expected input batch_size (192) to match target batch_size (352).
# Epoch 1 [Train]:  68% 34/50 [03:52<01:50,  6.90s/it, loss=0.0000, avg_loss=1.9816]Error in batch 35: Expected input batch_size (288) to match target batch_size (352).
# Epoch 1 [Train]:  72% 36/50 [04:03<01:30,  6.49s/it, loss=0.0000, avg_loss=1.9266]Error in batch 36: Expected input batch_size (192) to match target batch_size (352).
# Epoch 1 [Train]:  74% 37/50 [04:10<01:25,  6.61s/it, loss=0.0000, avg_loss=1.8745]Error in batch 37: Expected input batch_size (320) to match target batch_size (352).
# Epoch 1 [Train]:  76% 38/50 [04:14<01:10,  5.89s/it, loss=0.0000, avg_loss=1.8252]Error in batch 38: Expected input batch_size (224) to match target batch_size (352).
# Epoch 1 [Train]:  78% 39/50 [04:21<01:08,  6.19s/it, loss=0.0000, avg_loss=1.7784]Error in batch 39: Expected input batch_size (256) to match target batch_size (352).
# Epoch 1 [Train]:  80% 40/50 [04:25<00:55,  5.53s/it, loss=0.0000, avg_loss=1.7339]Error in batch 40: Expected input batch_size (256) to match target batch_size (352).
# Epoch 1 [Train]:  82% 41/50 [04:32<00:53,  5.93s/it, loss=0.0000, avg_loss=1.6916]Error in batch 41: Expected input batch_size (224) to match target batch_size (352).
# Epoch 1 [Train]:  84% 42/50 [04:36<00:44,  5.57s/it, loss=0.0000, avg_loss=1.6514]Error in batch 42: Expected input batch_size (320) to match target batch_size (352).
# Epoch 1 [Train]:  86% 43/50 [04:53<01:00,  8.69s/it, loss=0.0000, avg_loss=1.6129]Error in batch 43: Expected input batch_size (224) to match target batch_size (352).
# Epoch 1 [Train]: 100% 50/50 [05:36<00:00,  6.73s/it, loss=2.8465, avg_loss=1.7372]
# Validation:   0% 0/7 [00:00<?, ?it/s]Error in validation batch 0: Expected input batch_size (256) to match target batch_size (352).
# Validation:  14% 1/7 [00:12<01:14, 12.49s/it, loss=0.0000, avg_loss=0.0000]Error in validation batch 1: Expected input batch_size (256) to match target batch_size (352).
# Validation:  14% 1/7 [00:12<01:14, 12.49s/it, loss=0.0000, avg_loss=0.0000]Error in validation batch 2: Expected input batch_size (224) to match target batch_size (352).
# Validation:  43% 3/7 [00:24<00:31,  7.75s/it, loss=0.0000, avg_loss=0.0000]Error in validation batch 3: Expected input batch_size (224) to match target batch_size (352).
# Validation:  57% 4/7 [00:27<00:17,  5.98s/it, loss=0.0000, avg_loss=0.0000]Error in validation batch 4: Expected input batch_size (224) to match target batch_size (352).
# Validation:  71% 5/7 [00:36<00:13,  6.98s/it, loss=0.0000, avg_loss=0.0000]Error in validation batch 5: Expected input batch_size (256) to match target batch_size (352).
# Validation:  86% 6/7 [00:41<00:06,  6.26s/it, loss=0.0000, avg_loss=0.0000]Error in validation batch 6: Expected input batch_size (84) to match target batch_size (154).
# Validation: 100% 7/7 [00:41<00:00,  5.88s/it, loss=0.0000, avg_loss=0.0000]
# Train Loss: 1.7372, Val Loss: 0.0000
# Accuracy: 0.0000
# Character Accuracy: 0.0000
# Edit Distance: 0.0000
# Checkpoint saved to experiments/efficientnet_b0_20250522_080516/best_model.pth
# New best model saved! Loss: 0.0000
#
# ============================================================
# Epoch 2/100
# ============================================================
# Epoch 2 [Train]:   0% 0/50 [00:00<?, ?it/s]Error in batch 0: Expected input batch_size (320) to match target batch_size (352).
# Epoch 2 [Train]:   2% 1/50 [00:00<00:47,  1.03it/s, loss=0.0000, avg_loss=0.0000]Error in batch 1: Expected input batch_size (256) to match target batch_size (352).
# Epoch 2 [Train]:   6% 3/50 [00:01<00:19,  2.46it/s, loss=2.6020, avg_loss=0.8673]Error in batch 3: Expected input batch_size (224) to match target batch_size (352).
# Epoch 2 [Train]:   6% 3/50 [00:01<00:19,  2.46it/s, loss=0.0000, avg_loss=0.6505]Error in batch 4: Expected input batch_size (256) to match target batch_size (352).
# Epoch 2 [Train]:  10% 5/50 [00:01<00:12,  3.72it/s, loss=0.0000, avg_loss=0.5204]Error in batch 5: Expected input batch_size (256) to match target batch_size (352).
# Epoch 2 [Train]:  10% 5/50 [00:01<00:12,  3.72it/s, loss=0.0000, avg_loss=0.4337]Error in batch 6: Expected input batch_size (224) to match target batch_size (352).
# Epoch 2 [Train]:  16% 8/50 [00:02<00:08,  4.73it/s, loss=2.6559, avg_loss=0.6572]Error in batch 8: Expected input batch_size (224) to match target batch_size (352).
# Epoch 2 [Train]:  18% 9/50 [00:02<00:08,  4.67it/s, loss=0.0000, avg_loss=0.5842]Error in batch 9: Expected input batch_size (256) to match target batch_size (352).
# Epoch 2 [Train]:  42% 21/50 [00:04<00:05,  5.14it/s, loss=2.5648, avg_loss=1.7364]Error in batch 21: Expected input batch_size (288) to match target batch_size (352).
# Epoch 2 [Train]:  54% 27/50 [00:06<00:04,  4.79it/s, loss=2.4651, avg_loss=1.8436]Error in batch 27: Expected input batch_size (320) to match target batch_size (352).
# Epoch 2 [Train]:  60% 30/50 [00:06<00:04,  4.85it/s, loss=2.4751, avg_loss=1.8155]Error in batch 30: Expected input batch_size (256) to match target batch_size (352).
# Epoch 2 [Train]:  60% 30/50 [00:06<00:04,  4.85it/s, loss=0.0000, avg_loss=1.7569]Error in batch 31: Expected input batch_size (288) to match target batch_size (352).
# Epoch 2 [Train]:  64% 32/50 [00:06<00:02,  6.40it/s, loss=0.0000, avg_loss=1.7020]Error in batch 32: Expected input batch_size (256) to match target batch_size (352).
# Epoch 2 [Train]:  64% 32/50 [00:06<00:02,  6.40it/s, loss=0.0000, avg_loss=1.6504]Error in batch 33: Expected input batch_size (256) to match target batch_size (352).
# Epoch 2 [Train]:  68% 34/50 [00:07<00:02,  7.51it/s, loss=0.0000, avg_loss=1.6019]Error in batch 34: Expected input batch_size (288) to match target batch_size (352).
# Epoch 2 [Train]:  70% 35/50 [00:07<00:02,  6.45it/s, loss=0.0000, avg_loss=1.5561]Error in batch 35: Expected input batch_size (288) to match target batch_size (352).
# Epoch 2 [Train]:  72% 36/50 [00:07<00:02,  6.44it/s, loss=0.0000, avg_loss=1.5129]Error in batch 36: Expected input batch_size (288) to match target batch_size (352).
# Epoch 2 [Train]:  74% 37/50 [00:07<00:02,  5.86it/s, loss=0.0000, avg_loss=1.4720]Error in batch 37: Expected input batch_size (256) to match target batch_size (352).
# Epoch 2 [Train]:  76% 38/50 [00:07<00:01,  6.56it/s, loss=0.0000, avg_loss=1.4333]Error in batch 38: Expected input batch_size (288) to match target batch_size (352).
# Epoch 2 [Train]:  78% 39/50 [00:07<00:01,  6.22it/s, loss=0.0000, avg_loss=1.3965]Error in batch 39: Expected input batch_size (288) to match target batch_size (352).
# Epoch 2 [Train]:  80% 40/50 [00:08<00:01,  6.05it/s, loss=0.0000, avg_loss=1.3616]Error in batch 40: Expected input batch_size (256) to match target batch_size (352).
# Epoch 2 [Train]:  82% 41/50 [00:08<00:01,  5.36it/s, loss=0.0000, avg_loss=1.3284]Error in batch 41: Expected input batch_size (288) to match target batch_size (352).
# Epoch 2 [Train]:  86% 43/50 [00:09<00:02,  3.02it/s, loss=2.6455, avg_loss=1.3281]Error in batch 43: Expected input batch_size (224) to match target batch_size (352).
# Epoch 2 [Train]:  88% 44/50 [00:09<00:01,  3.59it/s, loss=0.0000, avg_loss=1.2979]Error in batch 44: Expected input batch_size (288) to match target batch_size (352).
# Epoch 2 [Train]:  88% 44/50 [00:09<00:01,  3.59it/s, loss=0.0000, avg_loss=1.2691]Error in batch 45: Expected input batch_size (256) to match target batch_size (352).
# Epoch 2 [Train]: 100% 50/50 [00:11<00:00,  4.35it/s, loss=2.4908, avg_loss=1.3534]
# Validation: 100% 7/7 [00:01<00:00,  4.34it/s, loss=2.8389, avg_loss=2.5603]
# Train Loss: 1.3534, Val Loss: 2.5603
# Accuracy: 0.0000
# Character Accuracy: 0.2833
# Edit Distance: 7.0631
#
# ============================================================
# Epoch 3/100
# ============================================================
# Epoch 3 [Train]:  28% 14/50 [00:03<00:07,  5.14it/s, loss=2.0858, avg_loss=2.4514]Error in batch 14: Expected input batch_size (320) to match target batch_size (352).
# Epoch 3 [Train]:  28% 14/50 [00:03<00:07,  5.14it/s, loss=0.0000, avg_loss=2.2879]Error in batch 15: Expected input batch_size (288) to match target batch_size (352).
# Epoch 3 [Train]:  32% 16/50 [00:03<00:04,  7.39it/s, loss=0.0000, avg_loss=2.1449]Error in batch 16: Expected input batch_size (256) to match target batch_size (352).
# Epoch 3 [Train]:  34% 17/50 [00:03<00:05,  5.72it/s, loss=0.0000, avg_loss=2.0188]Error in batch 17: Expected input batch_size (320) to match target batch_size (352).
# Epoch 3 [Train]:  34% 17/50 [00:03<00:05,  5.72it/s, loss=0.0000, avg_loss=1.9066]Error in batch 18: Expected input batch_size (320) to match target batch_size (352).
# Epoch 3 [Train]:  58% 29/50 [00:06<00:04,  4.67it/s, loss=2.2328, avg_loss=1.9834]Error in batch 29: Expected input batch_size (256) to match target batch_size (352).
# Epoch 3 [Train]:  70% 35/50 [00:07<00:02,  5.18it/s, loss=2.0834, avg_loss=1.9571]Error in batch 35: Expected input batch_size (288) to match target batch_size (352).
# Epoch 3 [Train]:  74% 37/50 [00:07<00:02,  5.17it/s, loss=2.0885, avg_loss=1.9078]Error in batch 37: Expected input batch_size (256) to match target batch_size (352).
# Epoch 3 [Train]:  74% 37/50 [00:07<00:02,  5.17it/s, loss=0.0000, avg_loss=1.8576]Error in batch 38: Expected input batch_size (288) to match target batch_size (352).
# Epoch 3 [Train]:  84% 42/50 [00:08<00:01,  4.93it/s, loss=1.9041, avg_loss=1.8226]Error in batch 42: Expected input batch_size (288) to match target batch_size (352).
# Epoch 3 [Train]:  92% 46/50 [00:09<00:01,  2.80it/s, loss=2.1122, avg_loss=1.8080]Error in batch 46: Expected input batch_size (288) to match target batch_size (352).
# Epoch 3 [Train]:  98% 49/50 [00:10<00:00,  3.83it/s, loss=1.9018, avg_loss=1.7819]Error in batch 49: Expected input batch_size (261) to match target batch_size (319).
# Epoch 3 [Train]: 100% 50/50 [00:10<00:00,  4.68it/s, loss=0.0000, avg_loss=1.7463]
# Validation:  14% 1/7 [00:00<00:04,  1.27it/s, loss=2.3702, avg_loss=2.3702]Error in validation batch 1: Expected input batch_size (320) to match target batch_size (352).
# Validation:  14% 1/7 [00:00<00:04,  1.27it/s, loss=0.0000, avg_loss=1.1851]Error in validation batch 2: Expected input batch_size (320) to match target batch_size (352).
# Validation:  43% 3/7 [00:01<00:01,  2.92it/s, loss=0.0000, avg_loss=0.7901]Error in validation batch 3: Expected input batch_size (320) to match target batch_size (352).
# Validation:  71% 5/7 [00:01<00:00,  3.48it/s, loss=1.9917, avg_loss=1.0802]Error in validation batch 6: Expected input batch_size (126) to match target batch_size (154).
# Validation: 100% 7/7 [00:01<00:00,  4.03it/s, loss=0.0000, avg_loss=0.9259]
# Train Loss: 1.7463, Val Loss: 0.9259
# Accuracy: 0.0000
# Character Accuracy: 0.2900
# Edit Distance: 5.2292
#
# ============================================================
# Epoch 4/100
# ============================================================
# Epoch 4 [Train]:  20% 10/50 [00:02<00:08,  4.58it/s, loss=1.9674, avg_loss=1.9764]Error in batch 10: Expected input batch_size (320) to match target batch_size (352).
# Epoch 4 [Train]:  20% 10/50 [00:02<00:08,  4.58it/s, loss=0.0000, avg_loss=1.7967]Error in batch 11: Expected input batch_size (320) to match target batch_size (352).
# Epoch 4 [Train]:  26% 13/50 [00:02<00:06,  5.84it/s, loss=1.9212, avg_loss=1.6681]Error in batch 13: Expected input batch_size (288) to match target batch_size (352).
# Epoch 4 [Train]:  68% 34/50 [00:07<00:03,  4.97it/s, loss=1.8520, avg_loss=1.7483]Error in batch 34: Expected input batch_size (288) to match target batch_size (352).
# Epoch 4 [Train]:  86% 43/50 [00:09<00:01,  5.12it/s, loss=1.6987, avg_loss=1.7101]Error in batch 43: Expected input batch_size (288) to match target batch_size (352).
# Epoch 4 [Train]:  90% 45/50 [00:09<00:00,  6.09it/s, loss=1.9884, avg_loss=1.6783]Error in batch 45: Expected input batch_size (288) to match target batch_size (352).
# Epoch 4 [Train]: 100% 50/50 [00:10<00:00,  4.82it/s, loss=1.7070, avg_loss=1.6465]
# Validation: 100% 7/7 [00:02<00:00,  3.39it/s, loss=2.1883, avg_loss=2.0185]
# Train Loss: 1.6465, Val Loss: 2.0185
# Accuracy: 0.0049
# Character Accuracy: 0.2672
# Edit Distance: 4.7767
#
# ============================================================
# Epoch 5/100
# ============================================================
# Epoch 5 [Train]:   6% 3/50 [00:01<00:16,  2.92it/s, loss=1.5855, avg_loss=1.6395]Error in batch 3: Expected input batch_size (288) to match target batch_size (352).
# Epoch 5 [Train]:  16% 8/50 [00:02<00:10,  4.12it/s, loss=1.5854, avg_loss=1.3967]Error in batch 8: Expected input batch_size (320) to match target batch_size (352).
# Epoch 5 [Train]:  22% 11/50 [00:02<00:08,  4.66it/s, loss=1.6563, avg_loss=1.3111]Error in batch 11: Expected input batch_size (288) to match target batch_size (352).
# Epoch 5 [Train]:  46% 23/50 [00:05<00:05,  5.03it/s, loss=1.6119, avg_loss=1.3502]Error in batch 23: Expected input batch_size (288) to match target batch_size (352).
# Epoch 5 [Train]:  46% 23/50 [00:05<00:05,  5.03it/s, loss=0.0000, avg_loss=1.2939]Error in batch 24: Expected input batch_size (320) to match target batch_size (352).
# Epoch 5 [Train]: 100% 50/50 [00:10<00:00,  4.83it/s, loss=1.6491, avg_loss=1.3817]
# Validation: 100% 7/7 [00:01<00:00,  3.55it/s, loss=1.8203, avg_loss=1.7666]
# Train Loss: 1.3817, Val Loss: 1.7666
# Accuracy: 0.0000
# Character Accuracy: 0.3149
# Edit Distance: 4.9272
#
# ============================================================
# Epoch 6/100
# ============================================================
# Epoch 6 [Train]:   8% 4/50 [00:01<00:17,  2.65it/s, loss=1.4918, avg_loss=1.4481]Error in batch 4: Expected input batch_size (288) to match target batch_size (352).
# Epoch 6 [Train]:  32% 16/50 [00:04<00:07,  4.30it/s, loss=1.4522, avg_loss=1.2687]Error in batch 16: Expected input batch_size (288) to match target batch_size (352).
# Epoch 6 [Train]: 100% 50/50 [00:10<00:00,  4.55it/s, loss=1.2340, avg_loss=1.2227]
# Validation: 100% 7/7 [00:01<00:00,  4.14it/s, loss=1.5166, avg_loss=1.5020]
# Train Loss: 1.2227, Val Loss: 1.5020
# Accuracy: 0.0000
# Character Accuracy: 0.3007
# Edit Distance: 4.0146
#
# ============================================================
# Epoch 7/100
# ============================================================
# Epoch 7 [Train]: 100% 50/50 [00:11<00:00,  4.36it/s, loss=1.0446, avg_loss=1.0555]
# Validation: 100% 7/7 [00:01<00:00,  4.79it/s, loss=1.3869, avg_loss=1.4563]
# Train Loss: 1.0555, Val Loss: 1.4563
# Accuracy: 0.0049
# Character Accuracy: 0.2788
# Edit Distance: 3.3447
#
# ============================================================
# Epoch 8/100
# ============================================================
# Epoch 8 [Train]: 100% 50/50 [00:11<00:00,  4.32it/s, loss=0.9709, avg_loss=0.8988]
# Validation: 100% 7/7 [00:01<00:00,  5.03it/s, loss=1.3196, avg_loss=1.2663]
# Train Loss: 0.8988, Val Loss: 1.2663
# Accuracy: 0.0000
# Character Accuracy: 0.3700
# Edit Distance: 3.6165
#
# ============================================================
# Epoch 9/100
# ============================================================
# Epoch 9 [Train]: 100% 50/50 [00:11<00:00,  4.21it/s, loss=0.6772, avg_loss=0.7656]
# Validation: 100% 7/7 [00:01<00:00,  4.92it/s, loss=1.4507, avg_loss=1.2813]
# Train Loss: 0.7656, Val Loss: 1.2813
# Accuracy: 0.0000
# Character Accuracy: 0.3950
# Edit Distance: 2.8252
#
# ============================================================
# Epoch 10/100
# ============================================================
# Epoch 10 [Train]: 100% 50/50 [00:11<00:00,  4.26it/s, loss=0.8308, avg_loss=0.6990]
# Validation: 100% 7/7 [00:01<00:00,  4.80it/s, loss=1.5723, avg_loss=1.2840]
# Train Loss: 0.6990, Val Loss: 1.2840
# Accuracy: 0.0097
# Character Accuracy: 0.4157
# Edit Distance: 3.0340
#
# ============================================================
# Epoch 11/100
# ============================================================
# Epoch 11 [Train]: 100% 50/50 [00:11<00:00,  4.21it/s, loss=0.6542, avg_loss=0.6562]
# Validation: 100% 7/7 [00:01<00:00,  5.04it/s, loss=1.3048, avg_loss=1.1512]
# Train Loss: 0.6562, Val Loss: 1.1512
# Accuracy: 0.0146
# Character Accuracy: 0.4734
# Edit Distance: 2.9272
# No improvement for 10 epochs. Early stopping.
#
# ============================================================
# Final evaluation on test set...
# ============================================================
# Validation:   0% 0/7 [00:26<?, ?it/s]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/vnlp_character_recognition/scripts/train.py", line 359, in <module>
#     main()
#   File "/content/drive/MyDrive/vnlp_character_recognition/scripts/train.py", line 340, in main
#     test_loss, test_metrics = validate(model, test_loader, criterion, device, config)
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/vnlp_character_recognition/scripts/train.py", line 176, in validate
#     target_lengths = target_lengths.to(device)  # ← Thêm dòng này
#                      ^^^^^^^^^^^^^^^^^
# AttributeError: 'list' object has no attribute 'to'
