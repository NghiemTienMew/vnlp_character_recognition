# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/vnlp_character_recognition/vnlp_character_recognition
# Out:
# /content/drive/MyDrive/vnlp_character_recognition/vnlp_character_recognition

# %%
# !pip install python-Levenshtein
# Out:
# Collecting python-Levenshtein
#   Downloading python_levenshtein-0.27.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting Levenshtein==0.27.1 (from python-Levenshtein)
#   Downloading levenshtein-0.27.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from Levenshtein==0.27.1->python-Levenshtein)
#   Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Downloading python_levenshtein-0.27.1-py3-none-any.whl (9.4 kB)
# Downloading levenshtein-0.27.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 17.7 MB/s eta 0:00:00
# Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 80.6 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.27.1 python-Levenshtein-0.27.1 rapidfuzz-3.13.0

# %%
# !python scripts/train.py --config config/model_config.yaml
# Out:
# Using GPU: Tesla T4
# 2025-05-23 02:15:24,001 - root - INFO - Save directory: experiments/efficientnet_b0_20250523_021523
# 2025-05-23 02:15:24,016 - root - INFO - Creating data loaders...
# Creating data loaders...
# Loaded CSV with 2000 records
# Dataset mode: train, Size: 1597
# Number of classes: 40
# Character mapping range: 0 to 39
# Loaded CSV with 2000 records
# Dataset mode: val, Size: 206
# Number of classes: 40
# Character mapping range: 0 to 39
# Loaded CSV with 2000 records
# Dataset mode: test, Size: 197
# Number of classes: 40
# Character mapping range: 0 to 39
# Dataset validation complete:
# - Train dataset: 1597 samples
# - Val dataset: 206 samples
# - Test dataset: 197 samples
# - Number of classes: 40
# 2025-05-23 02:15:24,048 - root - INFO - Data loaders created!
# 2025-05-23 02:15:24,049 - root - INFO - Creating model...
# 2025-05-23 02:15:24,514 - root - INFO - Model created!
# 2025-05-23 02:15:24,515 - root - INFO - Model info: {'backbone': 'efficientnet_b0', 'use_stn': True, 'decoder_type': 'rnn', 'attention_type': 'multi_head', 'rnn_type': 'gru', 'num_classes': 40, 'max_length': 10, 'encoder_hidden_size': 256, 'decoder_hidden_size': 256, 'embedding_dim': 256, 'use_language_model': True, 'total_parameters': 14627484}
# 2025-05-23 02:15:24,515 - root - INFO - Loss function created!
# 2025-05-23 02:15:24,516 - root - INFO - Setting up training...
# 2025-05-23 02:15:24,517 - root - INFO - Optimizer: adam, lr=0.001, weight_decay=1e-5
# 2025-05-23 02:15:24,517 - root - INFO - Starting training for 100 epochs...
# 2025-05-23 02:15:24,517 - root - INFO -
# ============================================================
# 2025-05-23 02:15:24,517 - root - INFO - Epoch 1/100
# 2025-05-23 02:15:24,517 - root - INFO - ============================================================
# Training: 100% 49/49 [00:13<00:00,  3.61it/s, loss=2.3627, avg_loss=3.0780]
# Validation: 100% 7/7 [00:01<00:00,  5.23it/s, loss=3.1734, avg_loss=3.2491, batch_acc=0.000]
#
# Computing metrics for 206 predictions and 206 targets
# Sample predictions: ['39-119', '39-717', '29-799']
# Sample targets: ['12C06406', '14A13847', '14N2332']
# 2025-05-23 02:15:39,430 - root - INFO - Debug: 0/206 correct predictions
# 2025-05-23 02:15:39,431 - root - INFO - Train Loss: 3.0780, Val Loss: 3.2491
# 2025-05-23 02:15:39,431 - root - INFO - Accuracy: 0.0000
# 2025-05-23 02:15:39,431 - root - INFO - Character Accuracy: 0.1552
# 2025-05-23 02:15:39,432 - root - INFO - Edit Distance: 6.0728
# Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:15:40,082 - root - INFO - Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:15:40,083 - root - INFO - New best model saved! Accuracy: 0.0000, Loss: 3.2491
# 2025-05-23 02:15:40,083 - root - INFO -
# ============================================================
# 2025-05-23 02:15:40,083 - root - INFO - Epoch 2/100
# 2025-05-23 02:15:40,083 - root - INFO - ============================================================
# Training: 100% 49/49 [00:12<00:00,  3.91it/s, loss=2.1939, avg_loss=2.3652]
# Validation: 100% 7/7 [00:01<00:00,  4.58it/s, loss=2.0678, avg_loss=2.1538, batch_acc=0.000]
#
# Computing metrics for 206 predictions and 206 targets
# Sample predictions: ['39A-0153', '30A-0177', '30A-7777']
# Sample targets: ['12C06406', '14A13847', '14N2332']
# 2025-05-23 02:15:54,144 - root - INFO - Debug: 0/206 correct predictions
# 2025-05-23 02:15:54,145 - root - INFO - Train Loss: 2.3652, Val Loss: 2.1538
# 2025-05-23 02:15:54,145 - root - INFO - Accuracy: 0.0000
# 2025-05-23 02:15:54,145 - root - INFO - Character Accuracy: 0.3281
# 2025-05-23 02:15:54,145 - root - INFO - Edit Distance: 5.1165
# Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:15:54,841 - root - INFO - Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:15:55,740 - root - INFO - New best model saved! Accuracy: 0.0000, Loss: 2.1538
# 2025-05-23 02:15:55,740 - root - INFO -
# ============================================================
# 2025-05-23 02:15:55,740 - root - INFO - Epoch 3/100
# 2025-05-23 02:15:55,740 - root - INFO - ============================================================
# Training: 100% 49/49 [00:12<00:00,  3.79it/s, loss=1.8519, avg_loss=2.0275]
# Validation: 100% 7/7 [00:01<00:00,  5.18it/s, loss=1.5887, avg_loss=1.8218, batch_acc=0.000]
#
# Computing metrics for 206 predictions and 206 targets
# Sample predictions: ['29C-00000', '14B-1127', '10V-2222']
# Sample targets: ['12C06406', '14A13847', '14N2332']
# 2025-05-23 02:16:10,017 - root - INFO - Debug: 0/206 correct predictions
# 2025-05-23 02:16:10,018 - root - INFO - Train Loss: 2.0275, Val Loss: 1.8218
# 2025-05-23 02:16:10,018 - root - INFO - Accuracy: 0.0000
# 2025-05-23 02:16:10,018 - root - INFO - Character Accuracy: 0.3781
# 2025-05-23 02:16:10,018 - root - INFO - Edit Distance: 4.7087
# Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:16:10,640 - root - INFO - Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:16:10,641 - root - INFO - New best model saved! Accuracy: 0.0000, Loss: 1.8218
# 2025-05-23 02:16:10,641 - root - INFO -
# ============================================================
# 2025-05-23 02:16:10,641 - root - INFO - Epoch 4/100
# 2025-05-23 02:16:10,641 - root - INFO - ============================================================
# Training: 100% 49/49 [00:13<00:00,  3.75it/s, loss=1.4922, avg_loss=1.7529]
# Validation: 100% 7/7 [00:01<00:00,  4.77it/s, loss=1.2446, avg_loss=1.5166, batch_acc=0.000]
#
# Computing metrics for 206 predictions and 206 targets
# Sample predictions: ['11C-00666', '14A-54777', '14A-22223']
# Sample targets: ['12C06406', '14A13847', '14N2332']
# 2025-05-23 02:16:25,177 - root - INFO - Debug: 0/206 correct predictions
# 2025-05-23 02:16:25,178 - root - INFO - Train Loss: 1.7529, Val Loss: 1.5166
# 2025-05-23 02:16:25,178 - root - INFO - Accuracy: 0.0000
# 2025-05-23 02:16:25,178 - root - INFO - Character Accuracy: 0.4216
# 2025-05-23 02:16:25,178 - root - INFO - Edit Distance: 4.1117
# Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:16:26,041 - root - INFO - Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:16:26,042 - root - INFO - New best model saved! Accuracy: 0.0000, Loss: 1.5166
# 2025-05-23 02:16:26,042 - root - INFO -
# ============================================================
# 2025-05-23 02:16:26,042 - root - INFO - Epoch 5/100
# 2025-05-23 02:16:26,042 - root - INFO - ============================================================
# Training: 100% 49/49 [00:17<00:00,  2.77it/s, loss=1.2977, avg_loss=1.5346]
# Validation: 100% 7/7 [00:01<00:00,  5.01it/s, loss=1.0979, avg_loss=1.3504, batch_acc=0.000]
#
# Computing metrics for 206 predictions and 206 targets
# Sample predictions: ['17C-04440', '14A-13577', '14N-7332']
# Sample targets: ['12C06406', '14A13847', '14N2332']
# 2025-05-23 02:16:45,113 - root - INFO - Debug: 0/206 correct predictions
# 2025-05-23 02:16:45,114 - root - INFO - Train Loss: 1.5346, Val Loss: 1.3504
# 2025-05-23 02:16:45,114 - root - INFO - Accuracy: 0.0000
# 2025-05-23 02:16:45,114 - root - INFO - Character Accuracy: 0.4126
# 2025-05-23 02:16:45,114 - root - INFO - Edit Distance: 3.5049
# Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:16:45,791 - root - INFO - Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:16:45,792 - root - INFO - New best model saved! Accuracy: 0.0000, Loss: 1.3504
# Checkpoint saved to experiments/efficientnet_b0_20250523_021523/checkpoint_epoch_5.pth
# 2025-05-23 02:16:46,460 - root - INFO -
# ============================================================
# 2025-05-23 02:16:46,460 - root - INFO - Epoch 6/100
# 2025-05-23 02:16:46,460 - root - INFO - ============================================================
# Training: 100% 49/49 [00:17<00:00,  2.84it/s, loss=1.3104, avg_loss=1.3765]
# Validation: 100% 7/7 [00:01<00:00,  4.83it/s, loss=1.0263, avg_loss=1.2070, batch_acc=0.000]
#
# Computing metrics for 206 predictions and 206 targets
# Sample predictions: ['27C-06409', '14A-15477', '14N-2332']
# Sample targets: ['12C06406', '14A13847', '14N2332']
# 2025-05-23 02:17:05,175 - root - INFO - Debug: 0/206 correct predictions
# 2025-05-23 02:17:05,176 - root - INFO - Train Loss: 1.3765, Val Loss: 1.2070
# 2025-05-23 02:17:05,176 - root - INFO - Accuracy: 0.0000
# 2025-05-23 02:17:05,176 - root - INFO - Character Accuracy: 0.4396
# 2025-05-23 02:17:05,176 - root - INFO - Edit Distance: 2.8689
# Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:17:05,861 - root - INFO - Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:17:05,861 - root - INFO - New best model saved! Accuracy: 0.0000, Loss: 1.2070
# 2025-05-23 02:17:05,862 - root - INFO -
# ============================================================
# 2025-05-23 02:17:05,862 - root - INFO - Epoch 7/100
# 2025-05-23 02:17:05,862 - root - INFO - ============================================================
# Training: 100% 49/49 [00:19<00:00,  2.51it/s, loss=1.1386, avg_loss=1.2416]
# Validation: 100% 7/7 [00:01<00:00,  4.30it/s, loss=0.9453, avg_loss=1.1339, batch_acc=0.000]
#
# Computing metrics for 206 predictions and 206 targets
# Sample predictions: ['17C-00006', '14A-19847', '14N-2332']
# Sample targets: ['12C06406', '14A13847', '14N2332']
# 2025-05-23 02:17:26,997 - root - INFO - Debug: 0/206 correct predictions
# 2025-05-23 02:17:26,997 - root - INFO - Train Loss: 1.2416, Val Loss: 1.1339
# 2025-05-23 02:17:26,997 - root - INFO - Accuracy: 0.0000
# 2025-05-23 02:17:26,998 - root - INFO - Character Accuracy: 0.4233
# 2025-05-23 02:17:26,998 - root - INFO - Edit Distance: 2.6019
# Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:17:27,765 - root - INFO - Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:17:27,766 - root - INFO - New best model saved! Accuracy: 0.0000, Loss: 1.1339
# 2025-05-23 02:17:27,767 - root - INFO -
# ============================================================
# 2025-05-23 02:17:27,767 - root - INFO - Epoch 8/100
# 2025-05-23 02:17:27,767 - root - INFO - ============================================================
# Training: 100% 49/49 [00:16<00:00,  2.96it/s, loss=1.0806, avg_loss=1.1726]
# Validation: 100% 7/7 [00:01<00:00,  4.99it/s, loss=0.9538, avg_loss=1.0710, batch_acc=0.000]
#
# Computing metrics for 206 predictions and 206 targets
# Sample predictions: ['12C-06406', '14A-19647', '14A-22332']
# Sample targets: ['12C06406', '14A13847', '14N2332']
# 2025-05-23 02:17:45,762 - root - INFO - Debug: 0/206 correct predictions
# 2025-05-23 02:17:45,762 - root - INFO - Train Loss: 1.1726, Val Loss: 1.0710
# 2025-05-23 02:17:45,762 - root - INFO - Accuracy: 0.0000
# 2025-05-23 02:17:45,762 - root - INFO - Character Accuracy: 0.4156
# 2025-05-23 02:17:45,763 - root - INFO - Edit Distance: 2.2427
# Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:17:46,449 - root - INFO - Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:17:46,449 - root - INFO - New best model saved! Accuracy: 0.0000, Loss: 1.0710
# 2025-05-23 02:17:46,450 - root - INFO -
# ============================================================
# 2025-05-23 02:17:46,450 - root - INFO - Epoch 9/100
# 2025-05-23 02:17:46,450 - root - INFO - ============================================================
# Training: 100% 49/49 [00:16<00:00,  2.93it/s, loss=1.1716, avg_loss=1.0736]
# Validation: 100% 7/7 [00:01<00:00,  3.90it/s, loss=0.8660, avg_loss=0.9865, batch_acc=0.000]
#
# Computing metrics for 206 predictions and 206 targets
# Sample predictions: ['12C-06406', '14A-19347', '14N-2332']
# Sample targets: ['12C06406', '14A13847', '14N2332']
# 2025-05-23 02:18:04,963 - root - INFO - Debug: 0/206 correct predictions
# 2025-05-23 02:18:04,964 - root - INFO - Train Loss: 1.0736, Val Loss: 0.9865
# 2025-05-23 02:18:04,964 - root - INFO - Accuracy: 0.0000
# 2025-05-23 02:18:04,964 - root - INFO - Character Accuracy: 0.4233
# 2025-05-23 02:18:04,965 - root - INFO - Edit Distance: 1.8398
# Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:18:05,931 - root - INFO - Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:18:05,931 - root - INFO - New best model saved! Accuracy: 0.0000, Loss: 0.9865
# 2025-05-23 02:18:05,931 - root - INFO -
# ============================================================
# 2025-05-23 02:18:05,932 - root - INFO - Epoch 10/100
# 2025-05-23 02:18:05,932 - root - INFO - ============================================================
# Training: 100% 49/49 [00:17<00:00,  2.80it/s, loss=0.9480, avg_loss=1.0035]
# Validation: 100% 7/7 [00:01<00:00,  4.89it/s, loss=0.8093, avg_loss=0.9324, batch_acc=0.000]
#
# Computing metrics for 206 predictions and 206 targets
# Sample predictions: ['12C-06406', '14A-13847', '14N-2332']
# Sample targets: ['12C06406', '14A13847', '14N2332']
# 2025-05-23 02:18:24,855 - root - INFO - Debug: 0/206 correct predictions
# 2025-05-23 02:18:24,856 - root - INFO - Train Loss: 1.0035, Val Loss: 0.9324
# 2025-05-23 02:18:24,856 - root - INFO - Accuracy: 0.0000
# 2025-05-23 02:18:24,856 - root - INFO - Character Accuracy: 0.4135
# 2025-05-23 02:18:24,856 - root - INFO - Edit Distance: 1.7136
# Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:18:25,555 - root - INFO - Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:18:25,556 - root - INFO - New best model saved! Accuracy: 0.0000, Loss: 0.9324
# Checkpoint saved to experiments/efficientnet_b0_20250523_021523/checkpoint_epoch_10.pth
# 2025-05-23 02:18:26,290 - root - INFO -
# ============================================================
# 2025-05-23 02:18:26,290 - root - INFO - Epoch 11/100
# 2025-05-23 02:18:26,290 - root - INFO - ============================================================
# Training: 100% 49/49 [00:18<00:00,  2.68it/s, loss=0.9835, avg_loss=0.9683]
# Validation: 100% 7/7 [00:01<00:00,  4.34it/s, loss=0.8114, avg_loss=0.9307, batch_acc=0.000]
#
# Computing metrics for 206 predictions and 206 targets
# Sample predictions: ['12C-06400', '14A-13847', '14N-2332']
# Sample targets: ['12C06406', '14A13847', '14N2332']
# 2025-05-23 02:18:46,203 - root - INFO - Debug: 0/206 correct predictions
# 2025-05-23 02:18:46,203 - root - INFO - Train Loss: 0.9683, Val Loss: 0.9307
# 2025-05-23 02:18:46,203 - root - INFO - Accuracy: 0.0000
# 2025-05-23 02:18:46,204 - root - INFO - Character Accuracy: 0.4114
# 2025-05-23 02:18:46,204 - root - INFO - Edit Distance: 1.6553
# Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:18:47,043 - root - INFO - Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:18:47,043 - root - INFO - New best model saved! Accuracy: 0.0000, Loss: 0.9307
# 2025-05-23 02:18:47,044 - root - INFO -
# ============================================================
# 2025-05-23 02:18:47,044 - root - INFO - Epoch 12/100
# 2025-05-23 02:18:47,044 - root - INFO - ============================================================
# Training: 100% 49/49 [00:17<00:00,  2.78it/s, loss=0.9579, avg_loss=0.9656]
# Validation: 100% 7/7 [00:01<00:00,  4.75it/s, loss=0.8070, avg_loss=0.9222, batch_acc=0.000]
#
# Computing metrics for 206 predictions and 206 targets
# Sample predictions: ['12C-06406', '14A-19947', '14N-2332']
# Sample targets: ['12C06406', '14A13847', '14N2332']
# 2025-05-23 02:19:06,181 - root - INFO - Debug: 0/206 correct predictions
# 2025-05-23 02:19:06,181 - root - INFO - Train Loss: 0.9656, Val Loss: 0.9222
# 2025-05-23 02:19:06,181 - root - INFO - Accuracy: 0.0000
# 2025-05-23 02:19:06,182 - root - INFO - Character Accuracy: 0.4017
# 2025-05-23 02:19:06,182 - root - INFO - Edit Distance: 1.5437
# Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:19:06,865 - root - INFO - Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:19:06,866 - root - INFO - New best model saved! Accuracy: 0.0000, Loss: 0.9222
# 2025-05-23 02:19:06,866 - root - INFO -
# ============================================================
# 2025-05-23 02:19:06,866 - root - INFO - Epoch 13/100
# 2025-05-23 02:19:06,866 - root - INFO - ============================================================
# Training: 100% 49/49 [00:16<00:00,  2.89it/s, loss=0.8774, avg_loss=0.9124]
# Validation: 100% 7/7 [00:01<00:00,  4.79it/s, loss=0.7709, avg_loss=0.8759, batch_acc=0.000]
#
# Computing metrics for 206 predictions and 206 targets
# Sample predictions: ['12C-06406', '14A-13847', '14N-2332']
# Sample targets: ['12C06406', '14A13847', '14N2332']
# 2025-05-23 02:19:25,282 - root - INFO - Debug: 0/206 correct predictions
# 2025-05-23 02:19:25,283 - root - INFO - Train Loss: 0.9124, Val Loss: 0.8759
# 2025-05-23 02:19:25,283 - root - INFO - Accuracy: 0.0000
# 2025-05-23 02:19:25,283 - root - INFO - Character Accuracy: 0.4082
# 2025-05-23 02:19:25,283 - root - INFO - Edit Distance: 1.4369
# Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:19:26,072 - root - INFO - Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:19:26,073 - root - INFO - New best model saved! Accuracy: 0.0000, Loss: 0.8759
# 2025-05-23 02:19:26,073 - root - INFO -
# ============================================================
# 2025-05-23 02:19:26,073 - root - INFO - Epoch 14/100
# 2025-05-23 02:19:26,073 - root - INFO - ============================================================
# Training: 100% 49/49 [00:17<00:00,  2.78it/s, loss=0.8714, avg_loss=0.8921]
# Validation: 100% 7/7 [00:02<00:00,  3.27it/s, loss=0.7992, avg_loss=0.8876, batch_acc=0.000]
#
# Computing metrics for 206 predictions and 206 targets
# Sample predictions: ['12C-06406', '14A-19847', '14N-2332']
# Sample targets: ['12C06406', '14A13847', '14N2332']
# 2025-05-23 02:19:45,847 - root - INFO - Debug: 0/206 correct predictions
# 2025-05-23 02:19:45,848 - root - INFO - Train Loss: 0.8921, Val Loss: 0.8876
# 2025-05-23 02:19:45,848 - root - INFO - Accuracy: 0.0000
# 2025-05-23 02:19:45,848 - root - INFO - Character Accuracy: 0.4039
# 2025-05-23 02:19:45,849 - root - INFO - Edit Distance: 1.4466
# 2025-05-23 02:19:45,849 - root - INFO -
# ============================================================
# 2025-05-23 02:19:45,849 - root - INFO - Epoch 15/100
# 2025-05-23 02:19:45,849 - root - INFO - ============================================================
# Training: 100% 49/49 [00:13<00:00,  3.56it/s, loss=0.8315, avg_loss=0.8780]
# Validation: 100% 7/7 [00:01<00:00,  5.10it/s, loss=0.7747, avg_loss=0.8579, batch_acc=0.000]
#
# Computing metrics for 206 predictions and 206 targets
# Sample predictions: ['12C-06406', '14A-19847', '14N-2332']
# Sample targets: ['12C06406', '14A13847', '14N2332']
# 2025-05-23 02:20:01,010 - root - INFO - Debug: 0/206 correct predictions
# 2025-05-23 02:20:01,010 - root - INFO - Train Loss: 0.8780, Val Loss: 0.8579
# 2025-05-23 02:20:01,011 - root - INFO - Accuracy: 0.0000
# 2025-05-23 02:20:01,011 - root - INFO - Character Accuracy: 0.4059
# 2025-05-23 02:20:01,011 - root - INFO - Edit Distance: 1.3981
# Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:20:01,706 - root - INFO - Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:20:01,707 - root - INFO - New best model saved! Accuracy: 0.0000, Loss: 0.8579
# Checkpoint saved to experiments/efficientnet_b0_20250523_021523/checkpoint_epoch_15.pth
# 2025-05-23 02:20:02,962 - root - INFO -
# ============================================================
# 2025-05-23 02:20:02,963 - root - INFO - Epoch 16/100
# 2025-05-23 02:20:02,963 - root - INFO - ============================================================
# Training: 100% 49/49 [00:18<00:00,  2.70it/s, loss=0.8279, avg_loss=0.8405]
# Validation: 100% 7/7 [00:01<00:00,  4.20it/s, loss=0.7663, avg_loss=0.8365, batch_acc=0.000]
#
# Computing metrics for 206 predictions and 206 targets
# Sample predictions: ['12C-06406', '14A-13847', '14N-2332']
# Sample targets: ['12C06406', '14A13847', '14N2332']
# 2025-05-23 02:20:22,781 - root - INFO - Debug: 0/206 correct predictions
# 2025-05-23 02:20:22,781 - root - INFO - Train Loss: 0.8405, Val Loss: 0.8365
# 2025-05-23 02:20:22,781 - root - INFO - Accuracy: 0.0000
# 2025-05-23 02:20:22,782 - root - INFO - Character Accuracy: 0.4049
# 2025-05-23 02:20:22,782 - root - INFO - Edit Distance: 1.3107
# Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:20:23,506 - root - INFO - Checkpoint saved to experiments/efficientnet_b0_20250523_021523/best_model.pth
# 2025-05-23 02:20:23,506 - root - INFO - New best model saved! Accuracy: 0.0000, Loss: 0.8365
# 2025-05-23 02:20:23,507 - root - INFO -
# ============================================================
# 2025-05-23 02:20:23,507 - root - INFO - Epoch 17/100
# 2025-05-23 02:20:23,507 - root - INFO - ============================================================
# Training:  41% 20/49 [00:06<00:05,  5.20it/s, loss=0.8478, avg_loss=0.8272]Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7b9ac0688680>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1618, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1564, in _shutdown_workers
#     self._pin_memory_thread.join()
#   File "/usr/lib/python3.11/threading.py", line 1119, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.11/threading.py", line 1139, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt:
# Training:  41% 20/49 [00:06<00:09,  3.12it/s, loss=0.8478, avg_loss=0.8272]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/vnlp_character_recognition/vnlp_character_recognition/scripts/train.py", line 663, in <module>
#     main()
#   File "/content/drive/MyDrive/vnlp_character_recognition/vnlp_character_recognition/scripts/train.py", line 543, in main
#     train_loss = train_epoch(
#                  ^^^^^^^^^^^^
#   File "/content/drive/MyDrive/vnlp_character_recognition/vnlp_character_recognition/scripts/train.py", line 275, in train_epoch
#     outputs = model(images, targets, teacher_forcing_ratio)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/vnlp_character_recognition/vnlp_character_recognition/models/vocr.py", line 183, in forward
#     decoder_outputs = self.decoder(
#                       ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/vnlp_character_recognition/vnlp_character_recognition/models/decoder.py", line 245, in forward
#     output, hidden, attention_weights = self.forward_step(
#                                         ^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/vnlp_character_recognition/vnlp_character_recognition/models/decoder.py", line 169, in forward_step
#     context, attention_weights = self.attention(
#                                  ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/vnlp_character_recognition/vnlp_character_recognition/models/attention.py", line 187, in forward
#     context = self.combine_heads(context)  # [batch_size, query_len, model_dim]
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/vnlp_character_recognition/vnlp_character_recognition/models/attention.py", line 139, in combine_heads
#     batch_size, _, seq_len, _ = x.size()
#                                 ^^^^^^^^
# KeyboardInterrupt
