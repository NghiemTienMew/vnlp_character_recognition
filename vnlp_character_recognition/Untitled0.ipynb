# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/vnlp_recog/vnlp_character_recognition
# Out:
# /content/drive/MyDrive/vnlp_recog/vnlp_character_recognition

# %%
# !pip install python-Levenshtein
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 57.3 MB/s eta 0:00:00
# ...

# %%
# !python test.py --image /content/drive/MyDrive/vnlp_recog/vnlp_character_recognition/one_row_36A02391.png --checkpoint experiments/best_model.pth
# Out:
# 🚀 VOCR Model Testing
# ...
# 💻 Using device: cuda
# 📂 Loading model from: experiments/best_model.pth
# ❌ Error loading model: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# ...

# %%
# !python scripts/train.py --config config/model_config.yaml
# Out:
# Using GPU: Tesla T4
# 2025-05-25 10:45:02,822 - root - INFO - Save directory: experiments/efficientnet_b0_20250525_104502
# 2025-05-25 10:45:02,836 - root - INFO - Creating data loaders...
# Creating data loaders...
# Loaded CSV with 2000 records
# Dataset mode: train, Size: 1597
# Number of classes: 40
# Character mapping range: 0 to 39
# Loaded CSV with 2000 records
# Dataset mode: val, Size: 206
# Number of classes: 40
# Character mapping range: 0 to 39
# Loaded CSV with 2000 records
# Dataset mode: test, Size: 197
# Number of classes: 40
# Character mapping range: 0 to 39
# Dataset validation complete:
# - Train dataset: 1597 samples
# - Val dataset: 206 samples
# - Test dataset: 197 samples
# - Number of classes: 40
# 2025-05-25 10:45:02,869 - root - INFO - Data loaders created!
# 2025-05-25 10:45:02,869 - root - INFO - Creating model...
# 2025-05-25 10:45:03,217 - root - INFO - Model created!
# ...
